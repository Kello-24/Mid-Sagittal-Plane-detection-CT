# %% [markdown]
# # Patient Data Oropharynx

# %% [markdown]
# ## Requirements

# %%
import os
import re

# %% [markdown]
# ## Patient ID encoder

# %%
def encode_decode_patient_id(patient_id: str, coding='encode') -> str:
    """
    Encodes or decodes a patient ID using a mapping from digits to letters.
    
    Parameters:
    - patient_id (str): The patient ID as an 8-character string.
        For encoding, the patient ID should consist of digits.
        For decoding, the patient ID should consist of letters as defined in the mapping.
    - coding (str): Operation mode: 'encode' maps digits to letters, 
                    'decode' converts letters back to digits.
    
    Returns:
    - str: The processed patient ID (encoded or decoded).
    
    Raises:
    - ValueError: If the patient_id does not meet the required format or if an invalid coding mode is provided.
    """
    # Define a bijective mapping from digits to letters.
    mapping = {
        "0": "Q",
        "1": "W",
        "2": "E",
        "3": "R",
        "4": "T",
        "5": "Y",
        "6": "U",
        "7": "I",
        "8": "O",
        "9": "P"
    }
    
    # Create the inverse mapping: letters to digits.
    reverse_mapping = {v: k for k, v in mapping.items()}
    
    def encode_patient_id(patient_id: str) -> str:
        if len(patient_id) != 8 or not patient_id.isdigit():
            raise ValueError("Patient ID for encoding must be an 8-digit string.")
        # Map each digit to its corresponding letter.
        return ''.join(mapping[digit] for digit in patient_id)
    
    def decode_patient_id(encoded_id: str) -> str:
        if len(encoded_id) != 8 or not all(char in reverse_mapping for char in encoded_id):
            raise ValueError("Encoded ID must be an 8-character string with valid mapping letters.")
        # Map each letter back to the corresponding digit.
        return ''.join(reverse_mapping[char] for char in encoded_id)
    
    if coding == 'encode':
        return encode_patient_id(patient_id)
    elif coding == 'decode':
        return decode_patient_id(patient_id)
    else:
        raise ValueError("Coding must be either 'encode' or 'decode'.")

# %%
def process_patient_folders(root_dir: str, coding = 'encode'):
    """
    Loops over all folders in the specified directory that match the pattern "*[8 digits]".
    For each matching folder, the function encodes the patient ID (mapping digits to letters)
    using the encode_decode_patient_id function (in 'encode' mode) and renames the folder.
    
    Parameters:
    - root_dir (str): The root directory containing patient folders.
    """
    # Regular expression pattern: an asterisk followed by exactly 8 digits.
    pattern_encode = re.compile(r'(\d{8})$')
    pattern_decode = re.compile(r'([A-Z]{8})$')
    
    for folder in os.listdir(root_dir):
        folder_path = os.path.join(root_dir, folder)
        if os.path.isdir(folder_path):
            if coding == 'encode':
                pattern = pattern_encode
            elif coding == 'decode':
                pattern = pattern_decode

            match = pattern.match(folder)

            if match:
                foldername = match.group(1)
                # Encode the patient ID using our mapping (digits -> letters).
                coded_id = encode_decode_patient_id(foldername, coding=coding)
                new_folder_name = f"{coded_id}"
                new_folder_path = os.path.join(root_dir, new_folder_name)
                
                # Check if a folder with the new name already exists.
                if os.path.exists(new_folder_path):
                    print(f"Folder '{new_folder_name}' already exists. Skipping folder '{folder}'.")
                else:
                    os.rename(folder_path, new_folder_path)
                    print(f"Renamed folder '{folder}' to '{new_folder_name}'")

# %%
root_dir = r"/home/loriskeller/Documents/Master Project/Patient data/patient_data_complete/06_midline_extraction"

process_patient_folders(root_dir, coding='decode')
# Out:
# Renamed folder 'WQYYIIWQ' to '10557710'
# Renamed folder 'WQYPPWWP' to '10599119'
# Renamed folder 'WQTRERIR' to '10432373'
# Renamed folder 'WQOYEUOQ' to '10852680'
# Renamed folder 'WQIEIOYY' to '10727855'
# Renamed folder 'WQORQQTI' to '10830047'
# Renamed folder 'WQUORQUU' to '10683066'
# Renamed folder 'WQUWPWOR' to '10619183'
# Renamed folder 'WQOTQTUT' to '10840464'
# Renamed folder 'WQTIRWOE' to '10473182'
# Renamed folder 'WQUYOTPI' to '10658497'
# Renamed folder 'WQIIPUOW' to '10779681'
# Renamed folder 'QRTWEQUI' to '03412067'
# Renamed folder 'WQURTEIR' to '10634273'
# Renamed folder 'QRRYRTWP' to '03353419'
# Renamed folder 'WQRYYTYP' to '10355459'
# Renamed folder 'WQUOUUTR' to '10686643'
# Renamed folder 'WQIOYEIO' to '10785278'
# Renamed folder 'QTOWIQRU' to '04817036'
# Renamed folder 'WQTIYOQY' to '10475805'
# Renamed folder 'QYYUIYTO' to '05567548'
# Renamed folder 'QWQOUYOO' to '01086588'
# Renamed folder 'WQYPWWQU' to '10591106'
# Renamed folder 'WQUTTOUR' to '10644863'
# Renamed folder 'WQUUQETE' to '10660242'
# Renamed folder 'QEPYOPIQ' to '02958970'
# Renamed folder 'QREIUTUY' to '03276465'
# Renamed folder 'WQIYROWT' to '10753814'
# Renamed folder 'WQTEPEUP' to '10429269'
# Renamed folder 'WQIQUWYT' to '10706154'
# Renamed folder 'WQYTWITY' to '10541745'
# Renamed folder 'QYUUPRIY' to '05669375'
# Renamed folder 'WQITYIIQ' to '10745770'
# Renamed folder 'QYWIEOUW' to '05172861'
# Renamed folder 'WQTTQYIU' to '10440576'
# Renamed folder 'WQIRUERU' to '10736236'
# Renamed folder 'WQQEIWYP' to '10027159'
# Renamed folder 'QIOPPPPO' to '07899998'
# Renamed folder 'QOWRPOPQ' to '08139890'
# Renamed folder 'WQYOTIQY' to '10584705'
# Renamed folder 'WQITYTOY' to '10745485'
# Renamed folder 'WQUTIPRP' to '10647939'
# Renamed folder 'WQEOTOEU' to '10284826'
# Renamed folder 'QTPEITPT' to '04927494'
# Renamed folder 'WQRQPIPY' to '10309795'
# Renamed folder 'QEQQPOWW' to '02009811'
# Renamed folder 'QTWWWIOO' to '04111788'
# Renamed folder 'WQUTUYYE' to '10646552'
# Renamed folder 'QYUTPROE' to '05649382'
# Renamed folder 'WQEQQIIQ' to '10200770'
# Renamed folder 'YPQYREYY' to '59053255'
# Renamed folder 'WQTPTORT' to '10494834'
# Renamed folder 'QWPWTEUQ' to '01914260'
# Renamed folder 'WQIPPYTW' to '10799541'
# Renamed folder 'QEWYIOQE' to '02157802'
# Renamed folder 'WQYWOOOW' to '10518881'
# Renamed folder 'UQWOOTQE' to '60188402'
# Renamed folder 'QWERYETP' to '01235249'
# Renamed folder 'WQUITWEU' to '10674126'
# Renamed folder 'WQRPUWTQ' to '10396140'
# Renamed folder 'QQIORETE' to '00783242'
# Renamed folder 'WQETWPTO' to '10241948'
# Renamed folder 'WQTTRWTQ' to '10443140'
# Renamed folder 'QTTEIQYQ' to '04427050'
# Renamed folder 'WQWIWIWY' to '10171715'
# Renamed folder 'WQURRQPY' to '10633095'
# Renamed folder 'WQUUYTIY' to '10665475'
# Renamed folder 'WQOQEWQW' to '10802101'
# Renamed folder 'QUEQQPYO' to '06200958'
# Renamed folder 'QIUPOEPW' to '07698291'
# Renamed folder 'WQOWIYIO' to '10817578'
# Renamed folder 'WQURTRUQ' to '10634360'
# Renamed folder 'WQWEYEWW' to '10125211'
# Renamed folder 'QQEWRROW' to '00213381'
# Renamed folder 'QWTIEQRO' to '01472038'
# Renamed folder 'WQYTOPUU' to '10548966'
# Renamed folder 'WQUOWWTE' to '10681142'
# Renamed folder 'WQUUYOTT' to '10665844'
# Renamed folder 'QRWWRREP' to '03113329'
# Renamed folder 'WQIRTEWT' to '10734214'
# Renamed folder 'QOETEQTU' to '08242046'
# Renamed folder 'WQUOEPQR' to '10682903'
# Renamed folder 'QRORWRTY' to '03831345'
# Renamed folder 'WQYWOYQY' to '10518505'
# Renamed folder 'WQIYTYII' to '10754577'
# Renamed folder 'QTQRTWTI' to '04034147'
# Renamed folder 'WQWUWEWU' to '10161216'
# Renamed folder 'QTEWTOUE' to '04214862'
# Renamed folder 'WQTUTYIT' to '10464574'
# Renamed folder 'QUIQYYRI' to '06705537'
# Renamed folder 'WQIUYYUI' to '10765567'
# Renamed folder 'WQOQRPUY' to '10803965'
# Renamed folder 'WQRPOPET' to '10398924'
# Renamed folder 'WQEYPWIE' to '10259172'
# Renamed folder 'WQRRQOOU' to '10330886'
# Renamed folder 'WQUOTOEI' to '10684827'
# Renamed folder 'WQURWWYP' to '10631159'
# Renamed folder 'QTIRYOPI' to '04735897'
# Renamed folder 'QQWQWRRO' to '00101338'
# Renamed folder 'WQTPWUYW' to '10491651'
# Renamed folder 'QQPYPORP' to '00959839'
# Renamed folder 'WQRYETQT' to '10352404'
# Renamed folder 'WQEWRUWW' to '10213611'
# Renamed folder 'QQETQPPQ' to '00240990'
# Renamed folder 'QEEQEEIW' to '02202271'
# Renamed folder 'QRRRPREI' to '03339327'
# Renamed folder 'WQTQTEYW' to '10404251'
# Renamed folder 'QTIIPWII' to '04779177'
# Renamed folder 'WQRUWURQ' to '10361630'
# Renamed folder 'WQRUORUO' to '10368368'
# Renamed folder 'QTEPTUPU' to '04294696'
# Renamed folder 'WQQORYIO' to '10083578'
# Renamed folder 'WQRTWRII' to '10341377'
# Renamed folder 'WQIQWOUT' to '10701864'
# Renamed folder 'WQIEUEEW' to '10726221'
# Renamed folder 'QEPEIOTY' to '02927845'
# Renamed folder 'QUPOEQPR' to '06982093'
# Renamed folder 'QEYYPOYT' to '02559854'
# Renamed folder 'QWUWUYRU' to '01616536'
# Renamed folder 'UQQOYOWT' to '60085814'
# Renamed folder 'QQUUOOYQ' to '00668850'
# Renamed folder 'WQUPRWQO' to '10693108'
# Renamed folder 'QERIUQPW' to '02376091'
# Renamed folder 'QUEUUETQ' to '06266240'
# Renamed folder 'QYEUIUYQ' to '05267650'
# Renamed folder 'WQQUOTQO' to '10068408'
# Renamed folder 'WQUOIQUR' to '10687063'
# Renamed folder 'WQURPYUP' to '10639569'
# Renamed folder 'WQUEWPWQ' to '10621910'
# Renamed folder 'QTIEIROQ' to '04727380'
# Renamed folder 'WQYPITQQ' to '10597400'
# Renamed folder 'QUQIOTEI' to '06078427'
# Renamed folder 'QYEWQQQR' to '05210003'
# Renamed folder 'WQOEYTQO' to '10825408'
# Renamed folder 'UQWIOPQY' to '60178905'
# Renamed folder 'WQOTOPQE' to '10848902'
# Renamed folder 'WQURQYPE' to '10630592'
# Renamed folder 'QWPOEOUP' to '01982869'
# Renamed folder 'WQUEQQTO' to '10620048'
# Renamed folder 'QROIORTW' to '03878341'
# Renamed folder 'WQTREEIP' to '10432279'
# Renamed folder 'WQYOIQEP' to '10587029'
# Renamed folder 'WQIWPYUU' to '10719566'
# Renamed folder 'QWWQETPT' to '01102494'
# Renamed folder 'QIWUEITQ' to '07162740'
# Renamed folder 'WQYEOETE' to '10528242'
# Renamed folder 'QRPYUQUI' to '03956067'
# Renamed folder 'QQWIWIQQ' to '00171700'
# Renamed folder 'WQIIOYIQ' to '10778570'
# Renamed folder 'WQIUUIRT' to '10766734'
# Renamed folder 'QIQQOTTP' to '07008449'
# Renamed folder 'QUUQTITP' to '06604749'
# Renamed folder 'WQUWQRWW' to '10610311'
# Renamed folder 'QEWYYEQU' to '02155206'
# Renamed folder 'WQQOUQWO' to '10086018'
# Renamed folder 'WQOEWRYY' to '10821355'
# Renamed folder 'QUOUPOUU' to '06869866'
# Renamed folder 'QTTTIOUI' to '04447867'
# Renamed folder 'WQEQWWOP' to '10201189'
# Renamed folder 'WQYIQIOI' to '10570787'
# Renamed folder 'WQUEQPYW' to '10620951'
# Renamed folder 'WQYPRPUY' to '10593965'
# Renamed folder 'WQQWRTER' to '10013423'
# Renamed folder 'QWPRTEPY' to '01934295'
# Renamed folder 'WQUEIPYT' to '10627954'
# Renamed folder 'WQOQWOTT' to '10801844'
# Renamed folder 'UQWOQYYO' to '60180558'
# Renamed folder 'QYYPRTUO' to '05593468'
# Renamed folder 'QQPOUIUR' to '00986763'
# Renamed folder 'WQIITPRP' to '10774939'
# Renamed folder 'QEOQITWU' to '02807416'
# Renamed folder 'UQQRREPT' to '60033294'
# Renamed folder 'WQRPRQWR' to '10393013'
# Renamed folder 'WQWUPQWW' to '10169011'
# Renamed folder 'QROYIEOQ' to '03857280'
# Renamed folder 'WQIPEREQ' to '10792320'
# Renamed folder 'QYIYTROQ' to '05754380'
# Renamed folder 'WQUPQYQW' to '10690501'
# Renamed folder 'QWIPRQIW' to '01793071'
# Renamed folder 'WQUEWOWY' to '10621815'
# Renamed folder 'QQOIRTRO' to '00873438'
# Renamed folder 'WQIIIIRO' to '10777738'
# Renamed folder 'WQYOEUTY' to '10582645'
# Renamed folder 'QRROEEWT' to '03382214'
# Renamed folder 'WQIWPUQQ' to '10719600'
# Renamed folder 'QUPTPUIR' to '06949673'
# Renamed folder 'WQEIUTUO' to '10276468'
# Renamed folder 'QREIEQUQ' to '03272060'
# Renamed folder 'QTPYOTEQ' to '04958420'
# Renamed folder 'WQUYPTPT' to '10659494'
# Renamed folder 'WQIQIOOU' to '10707886'
# Renamed folder 'WQQTUYQE' to '10046502'
# Renamed folder 'WQIIRRIR' to '10773373'
# Renamed folder 'QWOTPYOW' to '01849581'
# Renamed folder 'WQIOQWUR' to '10780163'
# Renamed folder 'QQEWPQOO' to '00219088'
# Renamed folder 'WQUURYUR' to '10663563'
# Renamed folder 'QEIIIOPT' to '02777894'
# Renamed folder 'QYURREWT' to '05633214'
# Renamed folder 'QRWPTUEQ' to '03194620'
# Renamed folder 'WQUERPEO' to '10623928'
# Renamed folder 'QIRIQIOT' to '07370784'
# Renamed folder 'WQOYUYUP' to '10856569'
# Renamed folder 'WQUWEORO' to '10612838'
# Renamed folder 'WQURPWRW' to '10639131'
# Renamed folder 'WQUOQPQW' to '10680901'
# Renamed folder 'QWWTYWYQ' to '01145150'
# Renamed folder 'WQIITIQO' to '10774708'
# Renamed folder 'WQRUQQEO' to '10360028'
# Renamed folder 'WQTRQROI' to '10430387'
# Renamed folder 'QEIUQOPT' to '02760894'
# Renamed folder 'QWYETUIT' to '01524674'
# Renamed folder 'WQUIPTQP' to '10679409'
# Renamed folder 'WQOYPUWO' to '10859618'
# Renamed folder 'WQUPORPO' to '10698398'
# Renamed folder 'WQUWIWIY' to '10617175'
# Renamed folder 'WQUWTTIP' to '10614479'
# Renamed folder 'WQUEWQTY' to '10621045'
# Renamed folder 'QUYOYOQP' to '06585809'
# Renamed folder 'WQIEYOWI' to '10725817'
# Renamed folder 'QRYUWYII' to '03561577'
# Renamed folder 'QYPEWWWE' to '05921112'
# Renamed folder 'WQIWQYIT' to '10710574'
# Renamed folder 'QUIIRRPI' to '06773397'
# Renamed folder 'WQQOQUQP' to '10080609'
# Renamed folder 'QTYTPPRI' to '04549937'
# Renamed folder 'WQRIUYEE' to '10376522'
# Renamed folder 'QTWEERPP' to '04122399'
# Renamed folder 'WQIIQOPR' to '10770893'
# Renamed folder 'QWWEOOOT' to '01128884'
# Renamed folder 'QIPEIWEU' to '07927126'
# Renamed folder 'WQTOTEYT' to '10484254'
# Renamed folder 'WQIITIUI' to '10774767'
# Renamed folder 'QWURUEYW' to '01636251'
# Renamed folder 'QYUQWYWI' to '05601517'
# Renamed folder 'WQYTIWRT' to '10547134'
# Renamed folder 'WQYPQPUU' to '10590966'
# Renamed folder 'QERPWIET' to '02391724'
# Renamed folder 'QQRUUEUP' to '00366269'
# Renamed folder 'QYWTIOYP' to '05147859'
# Renamed folder 'WQUPYTIW' to '10695471'
# Renamed folder 'QRQUERRR' to '03062333'
